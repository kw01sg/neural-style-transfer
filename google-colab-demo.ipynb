# %% [markdown]
# <a href="https://colab.research.google.com/github/kw01sg/neural-style-transfer/blob/google-colab/google-colab-demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kw01sg/neural-style-transfer.git
# Out:
# Cloning into 'neural-style-transfer'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 96 (delta 45), reused 62 (delta 22), pack-reused 0
# Unpacking objects: 100% (96/96), done.

# %%
# %cd neural-style-transfer
# Out:
# /content/neural-style-transfer

# %%
# !pip install tensorflow-gpu==2.0.0-beta1

# %%
# !python neural_transfer.py --help
# Out:
# usage: neural_transfer.py [-h] [--content-path CONTENT_PATH]
#                           [--style-path STYLE_PATH]
#                           [--style-weight STYLE_WEIGHT]
#                           [--content-weight CONTENT_WEIGHT]
#                           [--variation-weight VARIATION_WEIGHT]
#                           [-lr LEARNING_RATE] [--epochs EPOCHS]
#                           [--steps STEPS_PER_EPOCH]
#
# Perform neural style transfer.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --content-path CONTENT_PATH
#                         path of content image
#   --style-path STYLE_PATH
#                         path of style image
#   --style-weight STYLE_WEIGHT
#                         style weight
#   --content-weight CONTENT_WEIGHT
#                         content weight
#   --variation-weight VARIATION_WEIGHT
#                         variation weight
#   -lr LEARNING_RATE, --learning-rate LEARNING_RATE
#                         learning rate for Adam optimizer
#   --epochs EPOCHS       number of epochs
#   --steps STEPS_PER_EPOCH
#                         number of steps per epoch

# %%
# !python neural_transfer.py
# Out:
# Running neural style transfer with the following parameters:
#
# 	content_path: data/demo/chicago.jpg
# 	style_path: data/demo/candy.jpg
# 	style_weight: 1.0
# 	content_weight: 0.4
# 	variation_weight: 20000.0
# 	learning_rate: 10.0
# 	epochs: 10
# 	steps_per_epoch: 100
#
# WARNING: Logging before flag parsing goes to stderr.
# W0626 14:50:49.699892 140166550845312 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
# 100/100 [==================================================] - 15s - 149ms/step
# Epoch 2/10
# 100/100 [==================================================] - 14s - 135ms/step
# Epoch 3/10
# 100/100 [==================================================] - 14s - 136ms/step
# Epoch 4/10
# 100/100 [==================================================] - 14s - 137ms/step
# Epoch 5/10
# 100/100 [==================================================] - 13s - 134ms/step
# Epoch 6/10
# 100/100 [==================================================] - 13s - 133ms/step
# Epoch 7/10
# 100/100 [==================================================] - 13s - 133ms/step
# Epoch 8/10
# 100/100 [==================================================] - 13s - 134ms/step
# Epoch 9/10
# 100/100 [==================================================] - 14s - 136ms/step
# Epoch 10/10
# 100/100 [==================================================] - 14s - 135ms/step
# Total time: 136.3s
# Image saved at /content/neural-style-transfer/data/results/result.png.

# %%
from PIL import Image

Image.open('/content/neural-style-transfer/data/results/result.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x340 at 0x7FDC910794A8>
